# %% [markdown]
# ## Violations to Heckman Model Assumptions (Student-T)
#
# Explore violation to assumption that errors in outcome and missing pattern equations follow a join Gaussian. In this case we assume they are generated from a Student distribution.
#
# Author: Leo Guelman

# %% [markdown]
# ## Imports

# %%
import os
os.chdir('/Users/lguelman/Library/Mobile Documents/com~apple~CloudDocs/LG_Files/Development/UDA/python')

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import arviz as az
parameters = {'figure.figsize': (8, 4),
              'font.size': 6, 
              'axes.labelsize': 10}
plt.rcParams.update(parameters)
az.style.use("arviz-darkgrid")
from IPython.display import Image

import pystan
import multiprocessing
import seaborn as sns
import pickle
import random

from mde import MissingDataExperiments
from utils import plot_posterior, plot_mu_posterior

# %% [markdown]
# ### Simulation Params

# %%
B = 30 # Number of repetitions
N_samples = [50, 200, 1000]

random.seed(1)   
r_ints = []
for i in range(0,B):
    r_ints.append(random.randint(1,1000))
print(r_ints)
# Out:
# [138, 583, 868, 822, 783, 65, 262, 121, 508, 780, 461, 484, 668, 389, 808, 215, 97, 500, 30, 915, 856, 400, 444, 623, 781, 786, 3, 713, 457, 273]

# %% [markdown]
# ### Case 1: $\rho_{x,z} = 0$, $\rho_{y,d} =0$

# %%
case1_Heckman = dict.fromkeys(map(str, N_samples))
case1_OLS = dict.fromkeys(map(str, N_samples))

for i in range(len(N_samples)):
    for b in range(B):
        case1 = MissingDataExperiments(N = N_samples[i],
                                       alpha=0.5, beta=-0.5, delta=0.5, gamma=-2.5, sigma_y=1.0,
                                       rho_xz = 0.0, rho_yd = 0.0, m_error = False, distribution = 'Student',
                                       seed = r_ints[b])
        case1.generate_data()
        case1.stan_fit(type='Heckman')  
        if case1_Heckman[str(N_samples[i])] is None:
            case1_Heckman[str(N_samples[i])] = [case1]
        else:
            case1_Heckman[str(N_samples[i])].append(case1)
        
    
for i in range(len(N_samples)):
    for b in range(B):
        case1 = MissingDataExperiments(N = N_samples[i],
                                       alpha=0.5, beta=-0.5, delta=0.5, gamma=-2.5, sigma_y=1.0,
                                       rho_xz = 0.0, rho_yd = 0.0, m_error = False, distribution = 'Student',
                                       seed = r_ints[b])
        case1.generate_data()
        case1.stan_fit(type='OLS')  
        if case1_OLS[str(N_samples[i])] is None:
            case1_OLS[str(N_samples[i])] = [case1]
        else:
            case1_OLS[str(N_samples[i])].append(case1)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:4 of 2000 iterations ended with a divergence (0.2 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:50 of 2000 iterations ended with a divergence (2.5 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:5 of 2000 iterations ended with a divergence (0.25 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:8 of 2000 iterations ended with a divergence (0.4 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:1 of 2000 iterations ended with a divergence (0.05 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:1 of 2000 iterations ended with a divergence (0.05 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:3 of 2000 iterations ended with a divergence (0.15 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:7 of 2000 iterations ended with a divergence (0.35 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:2 of 2000 iterations ended with a divergence (0.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:12 of 2000 iterations ended with a divergence (0.6 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# WARNING:pystan:8 of 2000 iterations saturated the maximum tree depth of 10 (0.4 %)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.

# %%
plot_posterior(case1_Heckman, figsize=(30,10))
# Out:
# /Users/lguelman/Library/Mobile Documents/com~apple~CloudDocs/LG_Files/Development/UDA/python/utils.py:51: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   fig.subplots_adjust(hspace = .5, wspace=.5)

# %%
plot_posterior(case1_OLS, figsize=(30,10))

# %%
plot_mu_posterior(case1_Heckman, case1_OLS)

# %% [markdown]
# ### Case 2: $\rho_{x,z} = 0.8$, $\rho_{y,d} =0$

# %%
case2_Heckman = dict.fromkeys(map(str, N_samples))
case2_OLS = dict.fromkeys(map(str, N_samples))

for i in range(len(N_samples)):
    for b in range(B):
        case2 = MissingDataExperiments(N = N_samples[i],
                                       alpha=0.5, beta=-0.5, delta=0.5, gamma=-2.5, sigma_y=1.0,
                                       rho_xz = 0.8, rho_yd = 0.0, m_error = False, distribution = 'Student',
                                       seed = r_ints[b])
        case2.generate_data()
        case2.stan_fit(type='Heckman')  
        if case2_Heckman[str(N_samples[i])] is None:
            case2_Heckman[str(N_samples[i])] = [case2]
        else:
            case2_Heckman[str(N_samples[i])].append(case2)
        
    
for i in range(len(N_samples)):
    for b in range(B):
        case2 = MissingDataExperiments(N = N_samples[i],
                                       alpha=0.5, beta=-0.5, delta=0.5, gamma=-2.5, sigma_y=1.0,
                                       rho_xz = 0.8, rho_yd = 0.0, m_error = False, distribution = 'Student',
                                       seed = r_ints[b])
        case2.generate_data()
        case2.stan_fit(type='OLS')  
        if case2_OLS[str(N_samples[i])] is None:
            case2_OLS[str(N_samples[i])] = [case2]
        else:
            case2_OLS[str(N_samples[i])].append(case2)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:25 of 2000 iterations ended with a divergence (1.25 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:71 of 2000 iterations ended with a divergence (3.55 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:33 of 2000 iterations ended with a divergence (1.65 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:28 of 2000 iterations ended with a divergence (1.4 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:1 of 2000 iterations ended with a divergence (0.05 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:11 of 2000 iterations ended with a divergence (0.55 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:1 of 2000 iterations ended with a divergence (0.05 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:21 of 2000 iterations ended with a divergence (1.05 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:2 of 2000 iterations ended with a divergence (0.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:2 of 2000 iterations ended with a divergence (0.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:7 of 2000 iterations ended with a divergence (0.35 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:18 of 2000 iterations ended with a divergence (0.9 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:3 of 2000 iterations ended with a divergence (0.15 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:19 of 2000 iterations ended with a divergence (0.95 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:12 of 2000 iterations ended with a divergence (0.6 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.

# %%
plot_posterior(case2_Heckman, figsize=(30,10))
# Out:
# /Users/lguelman/Library/Mobile Documents/com~apple~CloudDocs/LG_Files/Development/UDA/python/utils.py:51: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   fig.subplots_adjust(hspace = .5, wspace=.5)

# %%
plot_posterior(case2_OLS, figsize=(30,10))

# %%
plot_mu_posterior(case2_Heckman, case2_OLS)

# %% [markdown]
# ### Case 3: $\rho_{x,z} = 0$, $\rho_{y,d} =0.8$

# %%
case3_Heckman = dict.fromkeys(map(str, N_samples))
case3_OLS = dict.fromkeys(map(str, N_samples))

for i in range(len(N_samples)):
    for b in range(B):
        case3 = MissingDataExperiments(N = N_samples[i],
                                       alpha=0.5, beta=-0.5, delta=0.5, gamma=-2.5, sigma_y=1.0,
                                       rho_xz = 0.0, rho_yd = 0.8, m_error = False, distribution = 'Student',
                                       seed = r_ints[b])
        case3.generate_data()
        case3.stan_fit(type='Heckman')  
        if case3_Heckman[str(N_samples[i])] is None:
            case3_Heckman[str(N_samples[i])] = [case3]
        else:
            case3_Heckman[str(N_samples[i])].append(case3)
        
    
for i in range(len(N_samples)):
    for b in range(B):
        case3 = MissingDataExperiments(N = N_samples[i],
                                       alpha=0.5, beta=-0.5, delta=0.5, gamma=-2.5, sigma_y=1.0,
                                       rho_xz = 0.0, rho_yd = 0.8, m_error = False, distribution = 'Student',
                                       seed = r_ints[b])
        case3.generate_data()
        case3.stan_fit(type='OLS')  
        if case3_OLS[str(N_samples[i])] is None:
            case3_OLS[str(N_samples[i])] = [case3]
        else:
            case3_OLS[str(N_samples[i])].append(case3)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:15 of 2000 iterations ended with a divergence (0.75 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:35 of 2000 iterations ended with a divergence (1.75 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:9 of 2000 iterations ended with a divergence (0.45 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:2 of 2000 iterations ended with a divergence (0.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:39 of 2000 iterations ended with a divergence (1.95 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:15 of 2000 iterations ended with a divergence (0.75 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:10 of 2000 iterations ended with a divergence (0.5 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:12 of 2000 iterations ended with a divergence (0.6 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:81 of 2000 iterations ended with a divergence (4.05 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:8 of 2000 iterations ended with a divergence (0.4 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:13 of 2000 iterations ended with a divergence (0.65 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:5 of 2000 iterations ended with a divergence (0.25 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:15 of 2000 iterations ended with a divergence (0.75 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:22 of 2000 iterations ended with a divergence (1.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:3 of 2000 iterations ended with a divergence (0.15 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:12 of 2000 iterations ended with a divergence (0.6 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:1 of 2000 iterations ended with a divergence (0.05 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:30 of 2000 iterations ended with a divergence (1.5 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:6 of 2000 iterations ended with a divergence (0.3 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:12 of 2000 iterations ended with a divergence (0.6 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:12 of 2000 iterations ended with a divergence (0.6 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:18 of 2000 iterations ended with a divergence (0.9 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:12 of 2000 iterations ended with a divergence (0.6 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:8 of 2000 iterations ended with a divergence (0.4 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:4 of 2000 iterations ended with a divergence (0.2 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:3 of 2000 iterations ended with a divergence (0.15 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:1 of 2000 iterations ended with a divergence (0.05 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:1 of 2000 iterations ended with a divergence (0.05 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:70 of 2000 iterations ended with a divergence (3.5 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:1 of 2000 iterations ended with a divergence (0.05 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:12 of 2000 iterations ended with a divergence (0.6 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:30 of 2000 iterations ended with a divergence (1.5 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:41 of 2000 iterations ended with a divergence (2.05 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:3 of 2000 iterations ended with a divergence (0.15 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:36 of 2000 iterations ended with a divergence (1.8 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.

# %%
plot_posterior(case3_Heckman, figsize=(30,10))
# Out:
# /Users/lguelman/Library/Mobile Documents/com~apple~CloudDocs/LG_Files/Development/UDA/python/utils.py:51: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   fig.subplots_adjust(hspace = .5, wspace=.5)

# %%
plot_posterior(case3_OLS, figsize=(30,10))

# %%
plot_mu_posterior(case3_Heckman, case3_OLS)

# %% [markdown]
# ### Case 4: $\rho_{x,z} = 0.8$, $\rho_{y,d} =0.8$

# %%
case4_Heckman = dict.fromkeys(map(str, N_samples))
case4_OLS = dict.fromkeys(map(str, N_samples))

for i in range(len(N_samples)):
    for b in range(B):
        case4 = MissingDataExperiments(N = N_samples[i],
                                       alpha=0.5, beta=-0.5, delta=0.5, gamma=-2.5, sigma_y=1.0,
                                       rho_xz = 0.8, rho_yd = 0.8, m_error = False, distribution = 'Student',
                                       seed = r_ints[b])
        case4.generate_data()
        case4.stan_fit(type='Heckman')  
        if case4_Heckman[str(N_samples[i])] is None:
            case4_Heckman[str(N_samples[i])] = [case4]
        else:
            case4_Heckman[str(N_samples[i])].append(case4)
        
    
for i in range(len(N_samples)):
    for b in range(B):
        case4 = MissingDataExperiments(N = N_samples[i],
                                       alpha=0.5, beta=-0.5, delta=0.5, gamma=-2.5, sigma_y=1.0,
                                       rho_xz = 0.8, rho_yd = 0.8, m_error = False, distribution = 'Student',
                                       seed = r_ints[b])
        case4.generate_data()
        case4.stan_fit(type='OLS')  
        if case4_OLS[str(N_samples[i])] is None:
            case4_OLS[str(N_samples[i])] = [case4]
        else:
            case4_OLS[str(N_samples[i])].append(case4)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:5 of 2000 iterations ended with a divergence (0.25 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:3 of 2000 iterations ended with a divergence (0.15 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:26 of 2000 iterations ended with a divergence (1.3 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:27 of 2000 iterations ended with a divergence (1.35 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:19 of 2000 iterations ended with a divergence (0.95 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:30 of 2000 iterations ended with a divergence (1.5 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:13 of 2000 iterations ended with a divergence (0.65 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:24 of 2000 iterations ended with a divergence (1.2 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:2 of 2000 iterations ended with a divergence (0.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:43 of 2000 iterations ended with a divergence (2.15 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:52 of 2000 iterations ended with a divergence (2.6 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:6 of 2000 iterations ended with a divergence (0.3 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:33 of 2000 iterations ended with a divergence (1.65 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:21 of 2000 iterations ended with a divergence (1.05 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:3 of 2000 iterations ended with a divergence (0.15 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:11 of 2000 iterations ended with a divergence (0.55 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:42 of 2000 iterations ended with a divergence (2.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:12 of 2000 iterations ended with a divergence (0.6 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:46 of 2000 iterations ended with a divergence (2.3 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:6 of 2000 iterations ended with a divergence (0.3 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:4 of 2000 iterations ended with a divergence (0.2 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:3 of 2000 iterations ended with a divergence (0.15 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:1 of 2000 iterations ended with a divergence (0.05 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:5 of 2000 iterations ended with a divergence (0.25 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:2 of 2000 iterations ended with a divergence (0.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:62 of 2000 iterations ended with a divergence (3.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:28 of 2000 iterations ended with a divergence (1.4 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:40 of 2000 iterations ended with a divergence (2 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:7 of 2000 iterations ended with a divergence (0.35 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:2 of 2000 iterations ended with a divergence (0.1 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:32 of 2000 iterations ended with a divergence (1.6 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# WARNING:pystan:14 of 2000 iterations ended with a divergence (0.7 %).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_9fd5b75928620fd147b4b3153c0ab8c5 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_81d98457d415db41d19a30a7aa620401 NOW.

# %%
plot_posterior(case4_Heckman, figsize=(30,10))
# Out:
# /Users/lguelman/Library/Mobile Documents/com~apple~CloudDocs/LG_Files/Development/UDA/python/utils.py:51: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   fig.subplots_adjust(hspace = .5, wspace=.5)

# %%
plot_posterior(case4_OLS, figsize=(30,10))

# %%
plot_mu_posterior(case4_Heckman, case4_OLS)
